# %% [markdown]
# ## <font color=#000FF>讀整個套件的方法</font>
# > 直接輸入`import`加套件名

# %%
import numpy

# %% [markdown]
# ## <font color=#000ff>最大公因數</font>
# ```python
# def gcd(a,b):
#     while b :
#         a ,b = b ,a%b
#     return a
# ```

# %%
numpy.gcd(12,18)
# Out:
# 6

# %% [markdown]
# ## <font color=#000FF>縮寫套件名</font>
# > 給他一個as吧<P>
# > `imput` 套件名 `as`縮寫名

# %%
import numpy as np

# %%
np.gcd(12,18)
# Out:
# 6

# %% [markdown]
# ## <font color = #000ff>讓jupyter notebook 能夠出現matplotlib圖片</font>
# >`%matplotlib inline`
# ## <font color = #000ff>數據分析標準動作</font>
# > `
# %matplotlib inline
# import numpy as np
# import matplotlib.pyplot as plt
# `

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1,-2,-3,4,7,8,13,18,24])

# %%
plt.plot(np.random.rand(100))
