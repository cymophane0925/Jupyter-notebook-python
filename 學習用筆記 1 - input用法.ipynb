# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
L = [1,-3,2,-10,-9,12,-1,-12]

# %%
plot(L)

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f572d396fae9> in <module>
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
print("hello,world")
# Out:
# hello,world

# %%
name = '''x
y
z'''

# %%
print(name)
# Out:
# x
# y
# z

# %% [markdown]
# ## input用法

# %%
a = input("password: ")
# Out:
# password: gbc709g50122

# %%
a
# Out:
# 'gbc709g50122'

# %% [markdown]
# ## 匯率換算

# %%
US = input("美金價格= ")
TWD = float(US)*30.5
print('合台幣'+str(TWD)+'元')
# Out:
# 美金價格= 56556
# 合台幣1724958.0元

# %%
plot(randn(100))
