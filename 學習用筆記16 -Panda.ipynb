# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
 # %ls
# Out:
#  磁碟區 C 中的磁碟沒有標籤。
#  磁碟區序號:  C8D7-3837
#
#  C:\Users\edsonrose\Desktop\jupyternotebook\python Data science 的目錄
#
# 2020/03/24  下午 11:21    <DIR>          .
# 2020/03/24  下午 11:21    <DIR>          ..
# 2020/03/24  下午 11:13    <DIR>          .ipynb_checkpoints
# 2019/10/19  上午 02:10            14,746 2012.csv
# 2020/02/18  下午 11:26            16,172 colorimg.PNG
# 2020/02/24  下午 11:36            56,045 format.PNG
# 2019/10/19  上午 02:10             2,406 grades.csv
# 2020/02/24  下午 11:34            66,295 input用法.PNG
# 2020/03/03  下午 10:36             2,855 Jupyter 學習筆記 lesson 1.ipynb
# 2020/02/29  上午 11:11           119,613 list.PNG
# 2019/10/19  上午 02:10               999 names.csv
# 2019/10/19  上午 02:10           503,771 weather_2012.csv
# 2020/02/24  下午 11:35            54,695 while迴圈.PNG
# 2020/02/29  上午 11:12           177,514 切割.PNG
# 2020/02/20  下午 09:37             5,631 數學符號.PNG
# 2020/02/24  下午 10:28            53,190 練習用筆記 1 - input用法.ipynb
# ...

# %%
df = pd.read_csv("grades.csv") #df 是 dataframe縮寫

# %%
df.head() #看dataframe前五行資料的方法，dataframe 名稱.head ( )
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %%
df["國文"]
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %%
df.國文.values
# Out:
# array([ 9, 10, 13, 10, 13, 13, 11,  8,  9, 10, 14, 13, 11, 15,  8, 11, 14,
#        12,  9, 14, 13,  9, 12, 10, 10, 13, 13,  8, 15, 14,  8, 15,  9, 14,
#        13, 14, 12, 11,  8,  9, 12, 14, 14, 12, 13,  9, 14,  8, 15, 10, 12,
#        14, 12, 14, 15,  9, 11, 12, 10, 11, 14, 14,  8, 12,  9, 13, 10, 14,
#         8, 12,  9,  9, 10, 13, 14, 13,  9, 13, 12,  9, 13, 11, 11, 10, 10,
#        10, 11, 10, 11, 13,  8, 14,  8, 11, 10,  9,  8, 14, 15,  9],
#       dtype=int64)

# %%
cg = df.國文.values

# %%
cg.mean() #平均
# Out:
# 11.39

# %%
cg.std() #標準差
# Out:
# 2.1858407993264284

# %%
df.國文.plot()

# %%
df.國文.hist(bins = 15)

# %%
df.英文.values
# Out:
# array([10, 10, 15, 10, 12, 12, 13,  9,  9, 15,  9,  9, 15, 14, 13,  8,  9,
#        11,  8,  9,  9,  8, 14, 13, 12, 13, 11, 13, 14, 11, 10, 12, 11, 15,
#        12, 11, 13, 12,  8,  8, 13, 14, 12, 15, 13,  8, 12,  9, 14, 14, 12,
#        11,  9, 10, 15, 15, 14, 15, 13, 10, 12,  8, 10, 11, 14, 14, 14,  9,
#        14, 12, 13,  8,  9, 15,  9,  8, 12, 10, 13, 10, 15,  8, 14, 14,  8,
#        11, 10, 13,  8, 13, 11, 11, 12,  9,  9, 10, 10,  9,  9, 11],
#       dtype=int64)

# %%
df.國文.plot()
df.英文.plot()

# %%
df.國文.hist(bins = 15)
df.英文.hist(bins = 30)
